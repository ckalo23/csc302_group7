# %% [markdown]
# <a href="https://colab.research.google.com/github/ckalo23/csc302_group7/blob/main/New_Line_Graphs_302.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fig, ax = plt.subplots(figsize =(20, 10))
#ax.plot(name,vax)
ax.plot(name,deaths)
ax.set_ylabel("Deaths")
ax.set_xlabel("Continents")
#plt.show()

fig, ax = plt.subplots(figsize =(20, 10))
ax.plot(name,vax)
ax.set_ylabel("Vaccinated")
ax.set_xlabel("Continents")
# Out:
# Text(0.5, 0, 'Continents')
